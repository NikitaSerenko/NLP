# %%
import re
from collections import Counter

# %%
with open('data/first.txt', encoding='utf-8') as file:
    text = file.read()

# %%
def text_to_wordlist(sentence):
    regexp = "[^а-яА-Яё]"
    sentence = re.sub(regexp, " ", sentence)
    result = sentence.lower().split()
    return result

# %%
def ngrams(word, n=3):
    length = len(word)
    result = [word[i:i+3] for i in range(0, length - 2)]
    return result

# %%
def make_dict(source_text, accuracy = 0., n=3):
    source_text = ["#"*(n - 1) + word + "#"*(n - 1) for word in text_to_wordlist(source_text)]
    all_ngrams = [ngram for word in source_text for ngram in ngrams(word)]
    counter = Counter(all_ngrams)
    amount_ngrams = len(all_ngrams)
    result_dict = dict()
    for item, count in sorted(counter.items(), key=lambda item: item[1], reverse=True):
        if count/amount_ngrams >= accuracy:
            result_dict[item] = count/amount_ngrams
    return result_dict

# %%
result_dict = make_dict(text)
print (result_dict)
# Out:
# {'о##': 0.018347568131002065, 'и##': 0.015263324800929153, 'а##': 0.014254422644367342, 'е##': 0.013482358261958635, '##с': 0.013234815955640418, '##п': 0.01312509450094802, '##в': 0.012878890261150442, '##н': 0.01265275701916245, '##о': 0.010367339401911027, 'я##': 0.0095123148952227, '##к': 0.009469496766562252, '##и': 0.009144346602046974, 'ь##': 0.008860676499671505, 'л##': 0.006749207530103152, 'й##': 0.006585963414585193, '#и#': 0.00657659694894072, '##б': 0.0063129978443748356, 'м##': 0.00629292684656525, '##т': 0.006291588780044611, '#по': 0.006167148593625184, '##д': 0.00590221142253866, 'у##': 0.005583751590626577, '#не': 0.005274658224358966, 'в##': 0.005237192361781074, '##м': 0.004910704130745156, 'то#': 0.004854505336878317, '#на': 0.004451747314165976, '##г': 0.004438366648959587, '##ч': 0.004391534320737221, 'на#': 0.004347378125556134, 'го#': 0.004240332803905013, 'к##': 0.004220261806095429, '#пр': 0.004003495029751909, 'т##': 0.003916520705910373, 'н##': 0.003837574781192672, '##р': 0.0037626430560368878, 'ы##': 0.0036850351978398254, '##з': 0.003563271144461676, '#он': 0.0034950297519090864, 'ть#': 0.003429464492397775, 'не#': 0.003365237299407103, 'но#': 0.0033304475698704887, 'ал#': 0.0032889675077306794, '##е': 0.0032782629755655672, '##у': 0.003251501645152787, '#в#': 0.0031431182569810275, 'ю##': 0.002875504952853226, 'что': 0.0027537408994750766, 'он#': 0.0027323318351448523, '#чт': 0.0027109227708146284, 'х##': 0.002674794974757375, '#то': 0.002630638779576288, 'сь#': 0.002629300713055649, 'с##': 0.0026119058482873417, '##а': 0.0025757780522300887, 'ли#': 0.0025530309213792255, 'ост': 0.0025409883226934745, '#бы': 0.0025222553914045283, 'ой#': 0.002491479861429831, '#ка': 0.002475423063182163, '#ко': 0.002459366264934495, 'ла#': 0.0024379572006042708, 'его': 0.0024312668680010756, 'ся#': 0.002424576535397881, '#за': 0.002309502814622926, '##л': 0.0022640085529212, 'ом#': 0.0022479517546735318, 'ак#': 0.0021904148942860544, '#го': 0.0021623154973526354, 'ого': 0.0021221735017334653, '##э': 0.0021101309030477143, 'аза': 0.0020311849783300126, '#вс': 0.0019375203218852822, 'каз': 0.0018773073284565269, 'ска': 0.0018652647297707759, 'ая#': 0.0018639266632501368, '#с#': 0.0018625885967294977, '#эт': 0.0018344891997960787, '#от': 0.0018197704680690495, 'при': 0.0018104040024245764, 'как': 0.0017836426720117965, '#ст': 0.0017742762063673234, 'ста': 0.0017649097407228503, 'про': 0.0017635716742022112, 'ово': 0.0017568813415990163, 'ени': 0.001722091612062402, 'тор': 0.001720753545541763, 'был': 0.001704696747294095, '#кн': 0.001702020614252817, 'сто': 0.001700682547732178, '#вы': 0.001683287682963871, 'кня': 0.0016672308847162029, '#ра': 0.0016498360199478958, 'ми#': 0.0016444837538653397, '#мо': 0.0016217366230144765, 'ать': 0.0015802565608746674, 'ей#': 0.0015494810308999702, '#ск': 0.001542790698296775, '#во': 0.0015334242326523022, 'ото': 0.001524057767007829, 'оро': 0.001520043567445912, 'пер': 0.001514691301363356, 'ло#': 0.001502648702677605, 'му#': 0.001498634503115688, 'ере': 0.0014598305740171568, '#до': 0.0014518021748933226, '##ж': 0.0014330692436043766, 'ем#': 0.0014303931105630985, 'это': 0.0013996175805884013, '#со': 0.0013822227158200942, 'ие#': 0.001364827851051787, 'зал': 0.001356799451927953, 'енн': 0.0013514471858453972, 'оло': 0.0013501091193247581, 'ет#': 0.001348771052804119, '##я': 0.0013474329862834802, 'лов': 0.001332714254556451, 'вор': 0.001328700054994534, '#св': 0.001328700054994534, 'оль': 0.001327361988473895, 'под': 0.0013220097223913389, 'ов#': 0.001311305190226227, 'да#': 0.001295248391978559, 'ств': 0.0012805296602515298, 'ил#': 0.0012778535272102518, 'ест': 0.0012765154606896127, '#та': 0.0012671489950451397, 'ый#': 0.0012564444628800277, '#ни': 0.0012484160637561935, '#бо': 0.0012390495981117206, '#де': 0.0012203166668227745, 'ова': 0.0012176405337814965, '#об': 0.0012042598685751064, '#но': 0.0012015837355338283, 'гов': 0.0012002456690131894, 'ала': 0.001189541136848077 ...

# %%
def check_word(word, result_dict, accuracy, n = 3):
    word = "#"*(n - 1) + word + "#"*(n - 1)
    text_ngrams = ngrams(word, n)
    flag = True
    for item in text_ngrams:
        if item not in result_dict or result_dict[item] < accuracy:
            print('miss')
            flag = False
            break
    if flag:
        print('exist')

# %%
check_word('###', result_dict, 0)
# Out:
# miss

# %%
check_word('питание', result_dict, 0.0001)
# Out:
# exist

# %%
check_word('пита', result_dict, 0.00001)
# Out:
# exist

# %%
class Node:
    def __init__(self, _letter):
        self.children = {}
        self.letter = _letter
        self.end = False
    def add_word(self, word):
        if word[0] in self.children.keys():
            if len(word) > 1:
                self.children[word[0]].add_word(word[1:])
        else:
            next_node = Node(word[0])
            self.children[word[0]] = next_node
            if len(word) > 1:
                next_node.add_word(word[1:])
            elif len(word) == 1:
                next_node.end = True

# %%
source_text = [word.lower() for word in text_to_wordlist(text)]

root = Node("~")
for word in source_text:
    root.add_word(word)

# %%
root.children['к'].children['н'].children['я'].children['з'].children['ь'].end
# Out:
# True

# %%
def find_close(root, word, accuraccy=2):
    word = word.lower()
    possible_answers = [(root, "", 0)]
    for letter in word:
        new_possible_answers = []
        for node, word, errors in possible_answers:
            for key, value in node.children.items():
                if letter == key:
                    new_possible_answers.append((value, word + key, errors))
                else:
                    if errors < accuraccy:
                        new_possible_answers.append((value, word + key, errors + 1))
        possible_answers = [answer for answer in possible_answers if answer[2] + len(word) - len(answer[1]) <= accuraccy 
                           and len(answer[0].children) == 0]
        possible_answers += new_possible_answers
    possible_answers = [answer for answer in possible_answers if answer[2] + len(word) - len(answer[1]) <= accuraccy 
                           and len(answer[0].children) == 0]
    for answer in possible_answers:
        print("Слово - {}, расстояние - {}".format(answer[1], answer[2]))
        
find_close(root, "военныйh")
# Out:
# Слово - верный, расстояние - 1
# Слово - вечный, расстояние - 1
# Слово - военную, расстояние - 2
# Слово - военной, расстояние - 1
# Слово - военное, расстояние - 2
# Слово - военные, расстояние - 1
# Слово - военных, расстояние - 1
# Слово - военный, расстояние - 0
# Слово - пленный, расстояние - 2
# Слово - военную, расстояние - 2
# Слово - военной, расстояние - 2
# Слово - военное, расстояние - 2
# Слово - военные, расстояние - 1
# Слово - военных, расстояние - 1
# Слово - военный, расстояние - 1
# Слово - военную, расстояние - 2
# Слово - военной, расстояние - 2
# Слово - военное, расстояние - 2
# Слово - военные, расстояние - 2
# Слово - военных, расстояние - 2
# Слово - военный, расстояние - 2
# Слово - военными, расстояние - 2
